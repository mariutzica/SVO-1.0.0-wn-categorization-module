# %%
import ontology_category as oc

# %%
svo = oc.init_svo()

# %%
svo.what_is('precipitation')
# Out:
#             term  wordnet_ss_index  \
# 0  precipitation                 0
# 1  precipitation                 1
# 2  precipitation                 2
# 3  precipitation                 3
# 4  precipitation                 4
# 5  precipitation                 5
#
#                                           definition pos amount.2 quantity.0  \
# 0  the quantity of water falling to earth at a sp...   n      yes        yes
# 1      the process of forming a chemical precipitate   n       no         no
# 2  the falling to earth of any form of water (rai...   n       no         no
# 3  the act of casting down or falling headlong fr...   n       no         no
# 4            an unexpected acceleration or hastening   n       no         no
# 5     overly eager speed (and possible carelessness)   n       no         no
#
#   property action.3 process.5 process phenomenon.0 object event.0 property.1  \
# 0      yes       no        no      no           no     no      no         no
# ...

# %%
svo.iscat('precipitation','object')
# Out:
#             term wordnet_ss_index  \
# 0  precipitation                0
# 1  precipitation                1
# 2  precipitation                2
# 3  precipitation                3
# 4  precipitation                4
# 5  precipitation                5
#
#                                           definition pos object
# 0  the quantity of water falling to earth at a sp...   n     no
# 1      the process of forming a chemical precipitate   n     no
# 2  the falling to earth of any form of water (rai...   n    yes
# 3  the act of casting down or falling headlong fr...   n     no
# 4            an unexpected acceleration or hastening   n     no
# 5     overly eager speed (and possible carelessness)   n     no
