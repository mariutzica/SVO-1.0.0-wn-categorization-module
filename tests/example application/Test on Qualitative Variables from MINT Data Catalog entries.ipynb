# %%
import pandas as pd
import sys
import unicodedata
import nltk
from SPARQLWrapper import SPARQLWrapper
from SPARQLWrapper import JSON as sqjson
#import hunspell -- installed and in package list but not working/not recognized??
sys.path.append("../../")
import ontology_category as oc
sys.path.pop()
svo = oc.init_svo()

# %%
def my_tokenizer(s):
    return s.replace('_',' ').split('/')

# %%
my_tokenizer('Yes/No/Don\'t Know')
# Out:
# ['Yes', 'No', "Don't Know"]

# %%
# look up term in ontology, return its class if exact match found
def search_ontology_for_class(term):
    sparql = SPARQLWrapper("http://sparql.geoscienceontology.org")
    sparql.setQuery("""
                    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
                    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

                    SELECT ?entity ?class
                    WHERE {{ ?entity a ?class .
                           # ?entity rdfs:label ?label .
                           FILTER regex(?label,"^{}$") .}}
                    """.format(term))
    sparql.setReturnFormat(sqjson)
    results = sparql.query().convert()

    data = []
    for result in results["results"]["bindings"]:
        c = result["class"]["value"].split('#')[1]
        if not c in data:
            data.append(c)

    return data

# %%
search_ontology_for_class('ocean')
# Out:
# ['SpatialPhenomenon', 'Phenomenon', 'NamedIndividual', 'Body']

# %%
is_noun = lambda pos: pos[:2] == 'NN'
is_verb = lambda pos: pos[:2] == 'VB'

# %%
def get_nouns(phrase):
    tokenized = nltk.word_tokenize(phrase)
    nouns = [word for (word, pos) in nltk.pos_tag(tokenized) if is_noun(pos)] 
    return nouns

def get_verbs(phrase):
    tokenized = nltk.word_tokenize(phrase)
    verbs = [word for (word, pos) in nltk.pos_tag(tokenized) if is_verb(pos)] 
    return verbs

# %%
def find_categories(var):
    categories = ['phenomenon','process','property','quantity','state','attribute']
    variable_classification = pd.DataFrame(columns=['variable name phrase','property nouns','process nouns','phenomenon nouns','state attribute or value nouns'])
    for var_string in var:
        var_name = my_tokenizer(var_string)
        print(var_name)
        #analyze first word in sequence:
        variable = var_name[0].split(': ')[-1].lower()
        print('Var name is: ', variable)
        var_nouns = get_nouns(variable)
        print('Nouns are: ',var_nouns)
        var_verbs = get_verbs(variable)
        print('Verbs are: ',var_verbs)
        index = len(variable_classification)
        variable_classification.loc[index,'variable name phrase'] = variable
        variable_classification = variable_classification.fillna('')
        for word in var_nouns:
            word_classes = search_ontology_for_class(word)
            if word_classes != []:
                #print(word,' found in ontology ...')
                #print('\tclasses are:',word_classes)
                if 'Phenomenon' in word_classes:
                    variable_classification.loc[index,'phenomenon nouns'] += word + ','
                if 'Property' in word_classes:
                    variable_classification.loc[index,'property nouns'] += word + ','
                if 'Process' in word_classes:
                    variable_classification.loc[index,'process nouns'] += word + ','
            else:
                #print(word,' NOT found in ontology ...')
                #print('\tpossible categories are:')
                prop = False
                state = False
                for cat in categories:
                    if svo.is_cat(word,cat,out='short'):
                        #print('\t\t',cat)
                        if cat == 'phenomenon':
                            variable_classification.loc[index,'phenomenon nouns'] += word + ','
                        elif cat == 'process':
                            variable_classification.loc[index,'process nouns'] += word + ','
                        elif cat == 'property' or cat == 'quantity' and not prop:
                            prop = True
                            variable_classification.loc[index,'property nouns'] += word + ','
                        elif cat == 'attribute' or cat == 'state' and not state:
                            state = True
                            variable_classification.loc[index,'state attribute or value nouns'] += word + ','
    return variable_classification

# %%
#simple categorizer:
def simple_categorizer(variable_classification):
    for index in variable_classification.index:
        procs_found = variable_classification.loc[index,'process nouns'].split(',')
        props_found = variable_classification.loc[index,'property nouns'].split(',')
        phens_found = variable_classification.loc[index,'phenomenon nouns'].split(',')
        attrs_found = variable_classification.loc[index,'state attribute or value nouns'].split(',')
        prop = ''
        proc = ''
        phen = ''
        attr = ''
        variable = variable_classification.loc[index,'variable name phrase']
        if len(props_found) == 1: #only one property present
            prop = props_found[0]
        elif len(props_found) > 1:
            for p in props_found: #add only props that are not categorized as anything else
                if not p in procs_found and not p in phens_found and not p in attrs_found:
                    prop = (prop + ' ' + p).lstrip()
            if prop == '': #no property that matches previous criteria, check if first or last terms in phrase are props
                var_words = variable.split()
                if 'of' in var_words:
                    indices = [i for i, x in enumerate(var_words) if x == 'of']
                    for i in indices:
                        if i>0 and var_words[i-1] in props_found:
                            prop = (prop + ' ' + var_words[i-1]).lstrip()
                elif var_words[-1] in props_found:
                    prop = var_words[-1]
                else:
                    prop = var_words[0]
        # remove property from other entries:
        for p in prop.split():
            if p in procs_found:
                procs_found.remove(p)
            if p in phens_found:
                phens_found.remove(p)
            if p in attrs_found:
                attrs_found.remove(p)
        if len(procs_found) == 1: #only one process present
            proc = procs_found[0]
        elif len(procs_found) > 1: #more than one process found
            for p in procs_found: #add only processes that are not categorized as anything else
                if not p in phens_found and not p in attrs_found:
                    proc = (proc + ' ' + p).lstrip()
            if proc == '': #no process that matches previous criteria, check if first or last terms in phrase are procs
                var_words = variable.split()
                if 'of' in var_words:
                    indices = [i for i, x in enumerate(var_words) if x == 'of']
                    for i in indices:
                        if i>0 and var_words[i-1] in procs_found:
                            proc = (proc + ' ' + var_words[i-1]).lstrip()
                elif var_words[-1] in procs_found:
                    proc = var_words[-1]
                else:
                    proc = var_words[0]
        # remove process from other entries:
        for p in proc.split():
            if p in phens_found:
                phens_found.remove(p)
            if p in attrs_found:
                attrs_found.remove(p)
        if len(phens_found) == 1: #only one phenomenon present
            phen = phens_found[0]
        elif len(phens_found) > 1: #more than one phenomenon found
            for p in phens_found: #add only phenomena that are not categorized as anything else
                if not p in attrs_found:
                    phen = (phen + ' ' + p).lstrip()
            if phen == '': #no phenomena that match previous criteria, check if first or last terms in phrase are phen
                var_words = variable.split()
                for p in phens_found:
                    phen = (phen + ' ' + p).lstrip()
        # remove phenomena from other entries:
        for p in phen.split():
            if p in attrs_found:
                attrs_found.remove(p)
        for a in attrs_found:
            attr = (attr + ' ' + a).lstrip()
        variable_classification.loc[index,'suggested phenomenon'] = phen
        variable_classification.loc[index,'suggested property'] = prop
        variable_classification.loc[index,'suggested process'] = proc
        variable_classification.loc[index,'suggested attribute or value'] = attr
        possible_name = ('_').join(phen.split())+'__'+('_').join(proc.split())+'_'+('_').join(prop.split())
        variable_classification.loc[index,'possible name'] = possible_name

# %%
#Variable information from 4 different files/sources:
lsms = pd.read_csv('LSMS.csv',index_col=False)
mics = pd.read_csv('MICS.csv',index_col=False)
ipums = pd.read_csv('IPUMS.csv',index_col=False)
dhs2 = pd.read_csv('DHS2.csv',index_col=False)

# %%
def parse_qualitative_variables(var, output_file):
    var_phrase_list = var['Question'].dropna().tolist()
    variable_classification = find_categories(var_phrase_list)
    simple_categorizer(variable_classification)
    variable_classification.to_csv(output_file)
    return variable_classification

# %%
lsms_classification = parse_qualitative_variables(lsms, 'breakdown_of_lsms_qualitative_variables.csv')
# Out:
# ['Sex']
# Var name is:  sex
# Nouns are:  ['sex']
# Verbs are:  []
# ['Yes', 'No']
# Var name is:  yes
# Nouns are:  ['yes']
# Verbs are:  []
# ['Yes', 'No', "Don't know"]
# Var name is:  yes
# Nouns are:  ['yes']
# Verbs are:  []
# ['Frequency']
# Var name is:  frequency
# Nouns are:  ['frequency']
# Verbs are:  []
# ['Satisfaction']
# Var name is:  satisfaction
# Nouns are:  ['satisfaction']
# Verbs are:  []
# ['Distance']
# Var name is:  distance
# Nouns are:  ['distance']
# Verbs are:  []
# ['Time']
# Var name is:  time
# Nouns are:  ['time']
# Verbs are:  []
# ['Time unit']
# Var name is:  time unit
# Nouns are:  ['time', 'unit']
# Verbs are:  []
# ['HOUSE ROSTER']
# Var name is:  house roster
# Nouns are:  ['house', 'roster']
# Verbs are:  []
# ['Part A: Household Roster']
# Var name is:  household roster
# Nouns are:  ['household', 'roster']
# Verbs are:  []
# ['Relationship to head']
# Var name is:  relationship to head
# Nouns are:  ['relationship']
# Verbs are:  ['head']
# ['Marital Status']
# Var name is:  marital status
# Nouns are:  ['status']
# Verbs are:  []
# ['Part C: Children of Household Members Who Are Living Elsewhere and Not Members of the Household ']
# Var name is:  children of household members who are living elsewhere and not members of the household
# Nouns are:  ['children', 'household', 'members', 'members', 'household']
# Verbs are:  ['are', 'living']
# ['Place of residence']
# Var name is:  place of residence
# Nouns are:  ['place', 'residence']
# Verbs are:  []
# ['EDUCATION']
# Var name is:  education
# Nouns are:  ['education']
# Verbs are:  []
# ['Short Module (Education)']
# Var name is:  short module (education)
# Nouns are:  ['module', 'education']
# Verbs are:  []
# ['Type of school']
# Var name is:  type of school
# Nouns are:  ['type', 'school']
# Verbs are:  []
# ['Part A: General Education ']
# Var name is:  general education
# Nouns are:  ['education']
# Verbs are:  []
# ['Literacy']
# Var name is:  literacy
# Nouns are:  ['literacy']
# Verbs are:  []
# ['Numeracy']
# Var name is:  numeracy
# Nouns are:  ['numeracy']
# Verbs are:  []
# ['School']
# Var name is:  school
# Nouns are:  ['school']
# Verbs are:  []
# ['Type of diploma attained']
# Var name is:  type of diploma attained
# Nouns are:  ['type', 'diploma']
# Verbs are:  ['attained']
# ['Major field of study in post-secondary education']
# Var name is:  major field of study in post-secondary education
# Nouns are:  ['field', 'study', 'education']
# Verbs are:  []
# ['Successfully completed school']
# Var name is:  successfully completed school
# Nouns are:  ['school']
# Verbs are:  ['completed']
# ['Public', 'Private']
# Var name is:  public
# Nouns are:  ['public']
# Verbs are:  []
# ['Part B: Education in Last 12 Months ']
# Var name is:  education in last 12 months
# Nouns are:  ['education', 'months']
# Verbs are:  []
# ['Who paid educational expenses']
# Var name is:  who paid educational expenses
# Nouns are:  ['expenses']
# Verbs are:  ['paid']
# ['Mode of transportation']
# Var name is:  mode of transportation
# Nouns are:  ['mode', 'transportation']
# Verbs are:  []
# ['Expanded Module, Additional Questions for Part B ']
# Var name is:  expanded module, additional questions for part b
# Nouns are:  ['module', 'questions', 'part', 'b']
# Verbs are:  ['expanded']
# ['Has a complete set of textbooks']
# Var name is:  has a complete set of textbooks
# Nouns are:  ['set', 'textbooks']
# Verbs are:  ['has']
# ['How textbooks obtained']
# Var name is:  how textbooks obtained
# Nouns are:  ['textbooks']
# Verbs are:  ['obtained']
# ['Textbooks shared ']
# Var name is:  textbooks shared
# Nouns are:  ['textbooks']
# Verbs are:  ['shared']
# ['Kind of meal received at school']
# Var name is:  kind of meal received at school
# Nouns are:  ['kind', 'meal', 'school']
# Verbs are:  ['received']
# ['Expenditure: Meal', 'snack - unit ']
# Var name is:  meal
# Nouns are:  ['meal']
# Verbs are:  []
# ['Part C: Apprenticeship and Training ']
# Var name is:  apprenticeship and training
# Nouns are:  ['apprenticeship', 'training']
# Verbs are:  []
# ['Ever been an apprentice ']
# Var name is:  ever been an apprentice
# Nouns are:  ['apprentice']
# Verbs are:  ['been']
# ['Ever received formal professional traini']
# Var name is:  ever received formal professional traini
# Nouns are:  ['professional', 'traini']
# Verbs are:  ['received']
# ['Part D: Distances to Local Schools']
# Var name is:  distances to local schools
# Nouns are:  ['distances', 'schools']
# Verbs are:  []
# ['Type of school']
# Var name is:  type of school
# Nouns are:  ['type', 'school']
# Verbs are:  []
# ['HEALTH']
# Var name is:  health
# Nouns are:  ['health']
# Verbs are:  []
# ['Short Module (Health)']
# Var name is:  short module (health)
# Nouns are:  ['module', 'health']
# Verbs are:  []
# ['Health compared with 1 year ago ']
# Var name is:  health compared with 1 year ago
# Nouns are:  ['health', 'year']
# Verbs are:  ['compared']
# ['Diarrhoea treatment']
# Var name is:  diarrhoea treatment
# Nouns are:  ['diarrhoea', 'treatment']
# Verbs are:  []
# ['Type of health insurance ']
# Var name is:  type of health insurance
# Nouns are:  ['type', 'health', 'insurance']
# Verbs are:  []
# ['Part A: Self Reported Health Status']
# Var name is:  self reported health status
# Nouns are:  ['self', 'health', 'status']
# Verbs are:  ['reported']
# ['Ability', 'Ease']
# Var name is:  ability
# Nouns are:  ['ability']
# Verbs are:  []
# ['Expanded Module, Additional Questions for Part A']
# Var name is:  expanded module, additional questions for part a
# Nouns are:  ['module', 'questions', 'part']
# Verbs are:  ['expanded']
# ['Frequency']
# Var name is:  frequency
# Nouns are:  ['frequency']
# Verbs are:  []
# ['Part B: Health Related Behaviors ']
# Var name is:  health related behaviors
# Nouns are:  ['health', 'behaviors']
# Verbs are:  ['related']
# ['Still smokes']
# Var name is:  still smokes
# Nouns are:  ['smokes']
# Verbs are:  []
# ['Still chews tobacco ']
# Var name is:  still chews tobacco
# Nouns are:  ['tobacco']
# Verbs are:  ['chews']
# ['Type of sports played']
# Var name is:  type of sports played
# Nouns are:  ['type', 'sports']
# Verbs are:  ['played']
# ['Respiration when playing sports']
# Var name is:  respiration when playing sports
# Nouns are:  ['respiration', 'playing', 'sports']
# Verbs are:  []
# ['Why plays sports']
# Var name is:  why plays sports
# Nouns are:  ['plays', 'sports']
# Verbs are:  []
# ['Sexually transmitted disease']
# Var name is:  sexually transmitted disease
# Nouns are:  ['disease']
# Verbs are:  ['transmitted']
# ['Protection against sexually transmitted disease']
# Var name is:  protection against sexually transmitted disease
# Nouns are:  ['protection', 'disease']
# Verbs are:  []
# ['Part C: Child Immunization']
# Var name is:  child immunization
# Nouns are:  ['child', 'immunization']
# Verbs are:  []
# ['up to date']
# Var name is:  up to date
# Nouns are:  ['date']
# Verbs are:  []
# ['Part D: Insurance Coverage ']
# Var name is:  insurance coverage
# Nouns are:  ['insurance', 'coverage']
# Verbs are:  []
# ['Type of health insurance ']
# Var name is:  type of health insurance
# Nouns are:  ['type', 'health', 'insurance']
# Verbs are:  []
# ['amount code ']
# Var name is:  amount code
# Nouns are:  ['amount', 'code']
# Verbs are:  []
# ['Part G: Directly Observed Activities of Daily Living ']
# Var name is:  directly observed activities of daily living
# Nouns are:  ['activities', 'living']
# Verbs are:  []
# ['Able to rotate shoulder ']
# Var name is:  able to rotate shoulder
# Nouns are:  ['shoulder']
# Verbs are:  ['rotate']
# ['Part H: Cognitive Functioning ']
# Var name is:  cognitive functioning
# Nouns are:  ['functioning']
# Verbs are:  []
# ['Correct', 'Incorrect']
# Var name is:  correct
# Nouns are:  ['correct']
# Verbs are:  []
# ['Present', 'Absent']
# Var name is:  present
# Nouns are:  ['present']
# Verbs are:  []
# ['Part E: Detailed Utilization and Expenditure ']
# Var name is:  detailed utilization and expenditure
# Nouns are:  ['utilization', 'expenditure']
# Verbs are:  []
# ['Health care provider']
# Var name is:  health care provider
# Nouns are:  ['health', 'care', 'provider']
# Verbs are:  []
# ['Purpose of the visit']
# Var name is:  purpose of the visit
# Nouns are:  ['purpose', 'visit']
# Verbs are:  []
# ['First visit', 'Follow up']
# Var name is:  first visit
# Nouns are:  ['visit']
# Verbs are:  []
# ['Treatment received']
# Var name is:  treatment received
# Nouns are:  ['treatment']
# Verbs are:  ['received']
# ['Reason for hospitalization']
# Var name is:  reason for hospitalization
# Nouns are:  ['reason', 'hospitalization']
# Verbs are:  []
# ['Type of hospital room ']
# Var name is:  type of hospital room
# Nouns are:  ['type', 'hospital', 'room']
# Verbs are:  []
# ['Treatment received']
# Var name is:  treatment received
# Nouns are:  ['treatment']
# Verbs are:  ['received']
# ['Health care facility']
# Var name is:  health care facility
# Nouns are:  ['health', 'care', 'facility']
# Verbs are:  []
# ['Employment']
# Var name is:  employment
# Nouns are:  ['employment']
# Verbs are:  []
# ['Part A: Labor Force Participation ']
# Var name is:  labor force participation
# Nouns are:  ['labor', 'force', 'participation']
# Verbs are:  []
# ['All yes', 'All No']
# Var name is:  all yes
# Nouns are:  ['yes']
# Verbs are:  []
# ['Main reason for not working']
# Var name is:  main reason for not working
# Nouns are:  ['reason']
# Verbs are:  ['working']
# ['Main reason for not looking for work']
# Var name is:  main reason for not looking for work
# Nouns are:  ['reason', 'work']
# Verbs are:  ['looking']
# ['Standard module, Part A: Labor Force Participation ']
# Var name is:  labor force participation
# Nouns are:  ['labor', 'force', 'participation']
# Verbs are:  []
# ['Method used to find work']
# Var name is:  method used to find work
# Nouns are:  ['method', 'work']
# Verbs are:  ['used', 'find']
# ['Weeks looked for work all at once']
# Var name is:  weeks looked for work all at once
# Nouns are:  ['weeks', 'work']
# Verbs are:  ['looked']
# ['Expanded module, Part A: Labor Force Participation ']
# Var name is:  labor force participation
# Nouns are:  ['labor', 'force', 'participation']
# Verbs are:  []
# ['Any yes or blank', 'All no']
# Var name is:  any yes or blank
# Nouns are:  ['yes', 'blank']
# Verbs are:  []
# ['Main reason for not working 5 years ago ']
# Var name is:  main reason for not working 5 years ago
# Nouns are:  ['reason', 'years']
# Verbs are:  ['working']
# ['Part B: Overview of Work in Last 7 Days and Last 12 Months']
# Var name is:  overview of work in last 7 days and last 12 months
# Nouns are:  ['overview', 'work', 'days', 'months']
# Verbs are:  []
# ['Place and employer of work ']
# Var name is:  place and employer of work
# Nouns are:  ['place', 'employer', 'work']
# Verbs are:  []
# ['Nb of activities in last 7 days ']
# Var name is:  nb of activities in last 7 days
# Nouns are:  ['nb', 'activities', 'days']
# Verbs are:  []
# ['Part C: Main and Secondary Job in the Last 7 Days']
# Var name is:  main and secondary job in the last 7 days
# Nouns are:  ['job', 'days']
# Verbs are:  []
# ['Place of work']
# Var name is:  place of work
# Nouns are:  ['place', 'work']
# Verbs are:  []
# ['Status in employment ']
# Var name is:  status in employment
# Nouns are:  ['status', 'employment']
# Verbs are:  []
# ['Type of employer ']
# Var name is:  type of employer
# Nouns are:  ['type', 'employer']
# Verbs are:  []
# ['Main reason for not receiving payment for work ']
# Var name is:  main reason for not receiving payment for work
# Nouns are:  ['reason', 'payment', 'work']
# Verbs are:  ['receiving']
# ['Standard module, Part C: Main and Secondary Job in the Last 7 Days ']
# Var name is:  main and secondary job in the last 7 days
# Nouns are:  ['job', 'days']
# Verbs are:  []
# ['Mode of transportation to work']
# Var name is:  mode of transportation to work
# Nouns are:  ['mode', 'transportation']
# Verbs are:  ['work']
# ['Before', 'After']
# Var name is:  before
# Nouns are:  []
# Verbs are:  []
# ['Main method to determine pay']
# Var name is:  main method to determine pay
# Nouns are:  ['method', 'pay']
# Verbs are:  ['determine']
# ['Main reason for not working in the job ']
# Var name is:  main reason for not working in the job
# Nouns are:  ['reason', 'job']
# Verbs are:  ['working']
# ['Expanded module, Part C: Main and Secondary Job in the Last 7 Days ']
# Var name is:  main and secondary job in the last 7 days
# Nouns are:  ['job', 'days']
# Verbs are:  []
# ['Main reason for losing the job']
# Var name is:  main reason for losing the job
# Nouns are:  ['reason', 'job']
# Verbs are:  ['losing']
# ['Type of work of owner ']
# Var name is:  type of work of owner
# Nouns are:  ['type', 'work', 'owner']
# Verbs are:  []
# ['Employed and paid directly by firm']
# Var name is:  employed and paid directly by firm
# Nouns are:  ['firm']
# Verbs are:  ['employed', 'paid']
# ['Time expected the work to last']
# Var name is:  time expected the work to last
# Nouns are:  ['time', 'work']
# Verbs are:  ['expected']
# ['Place obtained skills']
# Var name is:  place obtained skills
# Nouns are:  ['place', 'skills']
# Verbs are:  ['obtained']
# ['Type of employer ']
# Var name is:  type of employer
# Nouns are:  ['type', 'employer']
# Verbs are:  []
# ['Still learning to do the work well ']
# Var name is:  still learning to do the work well
# Nouns are:  ['work']
# Verbs are:  ['learning', 'do']
# ['Expanded module, Part E: Overview of Work Five Years Ago ']
# Var name is:  overview of work five years ago
# Nouns are:  ['overview', 'work', 'years']
# Verbs are:  []
# ['Most important activity 5 years ago']
# Var name is:  most important activity 5 years ago
# Nouns are:  ['activity', 'years']
# Verbs are:  []
# ['Anthropometry ']
# Var name is:  anthropometry
# Nouns are:  ['anthropometry']
# Verbs are:  []
# ['Reason child was not measured']
# Var name is:  reason child was not measured
# Nouns are:  ['reason', 'child']
# Verbs are:  ['was', 'measured']
# ['Height measured lying down or standing up ']
# Var name is:  height measured lying down or standing up
# Nouns are:  ['height']
# Verbs are:  ['measured', 'lying', 'standing']
# ['Housing']
# Var name is:  housing
# Nouns are:  ['housing']
# Verbs are:  []
# ['PART A.  DESCRIPTION OF THE DWELLING']
# Var name is:  part a.  description of the dwelling
# Nouns are:  ['part', 'a.', 'description', 'dwelling']
# Verbs are:  []
# ['Residence']
# Var name is:  residence
# Nouns are:  ['residence']
# Verbs are:  []
# ['Material of the external walls']
# Var name is:  material of the external walls
# Nouns are:  ['material', 'walls']
# Verbs are:  []
# ['Material of the roof']
# Var name is:  material of the roof
# Nouns are:  ['material', 'roof']
# Verbs are:  []
# ['Material of the floor']
# Var name is:  material of the floor
# Nouns are:  ['material', 'floor']
# Verbs are:  []
# ['Type of dwelling']
# Var name is:  type of dwelling
# Nouns are:  ['type']
# Verbs are:  ['dwelling']
# ['PART B. HOUSING SERVICES']
# Var name is:  part b. housing services
# Nouns are:  ['part', 'b.', 'housing', 'services']
# Verbs are:  []
# ['Main source of drinking water ']
# Var name is:  main source of drinking water
# Nouns are:  ['source', 'drinking', 'water']
# Verbs are:  []
# ['Type of water treatment']
# Var name is:  type of water treatment
# Nouns are:  ['type', 'water', 'treatment']
# Verbs are:  []
# ['Main source of bathing', 'washing water ']
# Var name is:  main source of bathing
# Nouns are:  ['source']
# Verbs are:  ['bathing']
# ['Placing of bathing']
# Var name is:  placing of bathing
# Nouns are:  ['placing']
# Verbs are:  ['bathing']
# ['Type of toilet facility']
# Var name is:  type of toilet facility
# Nouns are:  ['type', 'toilet', 'facility']
# Verbs are:  []
# ['Type of toilet disposal system']
# Var name is:  type of toilet disposal system
# Nouns are:  ['type', 'toilet', 'disposal', 'system']
# Verbs are:  []
# ['Toilet facility shared']
# Var name is:  toilet facility shared
# Nouns are:  ['toilet', 'facility']
# Verbs are:  ['shared']
# ['Source of lighting']
# Var name is:  source of lighting
# Nouns are:  ['source']
# Verbs are:  ['lighting']
# ['Type of electric meter']
# Var name is:  type of electric meter
# Nouns are:  ['type', 'meter']
# Verbs are:  []
# ['Cooking fuel']
# Var name is:  cooking fuel
# Nouns are:  ['fuel']
# Verbs are:  ['cooking']
# ['Heating fuel']
# Var name is:  heating fuel
# Nouns are:  ['fuel']
# Verbs are:  ['heating']
# ['Main Source of hot water']
# Var name is:  main source of hot water
# Nouns are:  ['source', 'water']
# Verbs are:  []
# ['Location ']
# Var name is:  location
# Nouns are:  ['location']
# Verbs are:  []
# ['Location of nearest telephone']
# Var name is:  location of nearest telephone
# Nouns are:  ['location', 'telephone']
# Verbs are:  []
# ['Disposal of Garbage']
# Var name is:  disposal of garbage
# Nouns are:  ['disposal', 'garbage']
# Verbs are:  []
# ['PART C: DWELLING EXPENDITURES']
# Var name is:  dwelling expenditures
# Nouns are:  ['dwelling', 'expenditures']
# Verbs are:  []
# ['How dwelling was obtained']
# Var name is:  how dwelling was obtained
# Nouns are:  ['dwelling']
# Verbs are:  ['was', 'obtained']
# ['Type of legal title to the dwelling']
# Var name is:  type of legal title to the dwelling
# Nouns are:  ['type', 'title', 'dwelling']
# Verbs are:  []
# ['Time unit']
# Var name is:  time unit
# Nouns are:  ['time', 'unit']
# Verbs are:  []
# ['From whom do you rent this dwelling']
# Var name is:  from whom do you rent this dwelling
# Nouns are:  ['dwelling']
# Verbs are:  ['do', 'rent']
# ['Rent inclusion']
# Var name is:  rent inclusion
# Nouns are:  ['rent', 'inclusion']
# Verbs are:  []
# ['Monthly payments']
# Var name is:  monthly payments
# Nouns are:  ['payments']
# Verbs are:  []
# ['Non-household member pay (part of) rent']
# Var name is:  non-household member pay (part of) rent
# Nouns are:  ['member', 'pay', 'part', 'rent']
# Verbs are:  []
# ['Who pay(part of) rent']
# Var name is:  who pay(part of) rent
# Nouns are:  ['part', 'rent']
# Verbs are:  ['pay']
# ['Part E: Planned Moves and Upgrades']
# Var name is:  planned moves and upgrades
# Nouns are:  ['moves', 'upgrades']
# Verbs are:  ['planned']
# ['Plan to move within 12 months']
# Var name is:  plan to move within 12 months
# Nouns are:  ['plan', 'months']
# Verbs are:  ['move']
# ['Motivation to move to new dwelling']
# Var name is:  motivation to move to new dwelling
# Nouns are:  ['motivation', 'dwelling']
# Verbs are:  ['move']
# ['Plan to buy or rent']
# Var name is:  plan to buy or rent
# Nouns are:  ['plan']
# Verbs are:  ['buy', 'rent']
# ['Consumption']
# Var name is:  consumption
# Nouns are:  ['consumption']
# Verbs are:  []
# ['Part A: Daily Consumption']
# Var name is:  daily consumption
# Nouns are:  ['consumption']
# Verbs are:  []
# ['Consumed item']
# Var name is:  consumed item
# Nouns are:  ['item']
# Verbs are:  ['consumed']
# ['Part B: Food Consumption']
# Var name is:  food consumption
# Nouns are:  ['food', 'consumption']
# Verbs are:  []
# ['Food Consumed']
# Var name is:  food consumed
# Nouns are:  ['food']
# Verbs are:  ['consumed']
# ['Quantity ']
# Var name is:  quantity
# Nouns are:  ['quantity']
# Verbs are:  []
# ['Part C: Non Food Consumption']
# Var name is:  non food consumption
# Nouns are:  ['food', 'consumption']
# Verbs are:  []
# ['Non food Consumed']
# Var name is:  non food consumed
# Nouns are:  ['food']
# Verbs are:  ['consumed']
# ['Part D: Remittances']
# Var name is:  remittances
# Nouns are:  ['remittances']
# Verbs are:  []
# ['Relationship to person']
# Var name is:  relationship to person
# Nouns are:  ['relationship', 'person']
# Verbs are:  []
# ['Kind of place recepient lives in']
# Var name is:  kind of place recepient lives in
# Nouns are:  ['kind', 'place', 'recepient', 'lives']
# Verbs are:  []
# ['Main Reason for Assistance']
# Var name is:  main reason for assistance
# Nouns are:  ['reason', 'assistance']
# Verbs are:  []
# ['Part E: Durables']
# Var name is:  durables
# Nouns are:  ['durables']
# Verbs are:  []
# ['Durable items']
# Var name is:  durable items
# Nouns are:  ['items']
# Verbs are:  []
# ['Purchased', 'Gift']
# Var name is:  purchased
# Nouns are:  []
# Verbs are:  ['purchased']
# ['Credit']
# Var name is:  credit
# Nouns are:  ['credit']
# Verbs are:  []
# ['Part B: Details of Credit']
# Var name is:  details of credit
# Nouns are:  ['details', 'credit']
# Verbs are:  []
# ['Agricultural reason for obtaining loan']
# Var name is:  agricultural reason for obtaining loan
# Nouns are:  ['reason', 'loan']
# Verbs are:  ['obtaining']
# ['Non-Agricultural reason for obtaining loan']
# Var name is:  non-agricultural reason for obtaining loan
# Nouns are:  ['reason', 'loan']
# Verbs are:  ['obtaining']
# [' Personal Use reason for obtaining loan']
# Var name is:   personal use reason for obtaining loan
# Nouns are:  ['use', 'reason', 'loan']
# Verbs are:  ['obtaining']
# ['Source of the loan']
# Var name is:  source of the loan
# Nouns are:  ['source', 'loan']
# Verbs are:  []
# ['Training provided']
# Var name is:  training provided
# Nouns are:  ['training']
# Verbs are:  ['provided']
# ['Time unit']
# Var name is:  time unit
# Nouns are:  ['time', 'unit']
# Verbs are:  []
# ['Quantity unit']
# Var name is:  quantity unit
# Nouns are:  ['quantity', 'unit']
# Verbs are:  []
# ['Harvest value calculated']
# Var name is:  harvest value calculated
# Nouns are:  ['value']
# Verbs are:  ['calculated']
# ['Collateral']
# Var name is:  collateral
# Nouns are:  ['collateral']
# Verbs are:  []
# ['Frequency']
# Var name is:  frequency
# Nouns are:  ['frequency']
# Verbs are:  []
# ['Frequency of payment']
# Var name is:  frequency of payment
# Nouns are:  ['frequency', 'payment']
# Verbs are:  []
# ['Part C: Credit History ']
# Var name is:  credit history
# Nouns are:  ['credit', 'history']
# Verbs are:  []
# ['Reson for credit being refused']
# Var name is:  reson for credit being refused
# Nouns are:  ['reson', 'credit']
# Verbs are:  ['being', 'refused']
# ['Reason for notattempting to borrow money']
# Var name is:  reason for notattempting to borrow money
# Nouns are:  ['reason', 'money']
# Verbs are:  ['notattempting', 'borrow']
# ['Relationship to Borrower']
# Var name is:  relationship to borrower
# Nouns are:  ['relationship']
# Verbs are:  ['borrower']
# ['Main reason borrower borrowed money']
# Var name is:  main reason borrower borrowed money
# Nouns are:  ['reason', 'borrower', 'money']
# Verbs are:  ['borrowed']
# ['Form of loan repayment']
# Var name is:  form of loan repayment
# Nouns are:  ['form', 'loan', 'repayment']
# Verbs are:  []
# ['Environment']
# Var name is:  environment
# Nouns are:  ['environment']
# Verbs are:  []
# ['Module 1: Environmental Priorities (Urban) ']
# Var name is:  environmental priorities (urban)
# Nouns are:  ['priorities']
# Verbs are:  []
# ['Urban', 'Rural']
# Var name is:  urban
# Nouns are:  []
# Verbs are:  []
# ['Urban Environmental problem']
# Var name is:  urban environmental problem
# Nouns are:  ['problem']
# Verbs are:  []
# ['Module 2: Environmental Priorities (Rural)']
# Var name is:  environmental priorities (rural)
# Nouns are:  ['priorities']
# Verbs are:  []
# ['Rural Environmental problem']
# Var name is:  rural environmental problem
# Nouns are:  ['problem']
# Verbs are:  []
# ['Module 3: Environmental Attitudes and Perceptions - Urban Air Quality']
# Var name is:  environmental attitudes and perceptions - urban air quality
# Nouns are:  ['attitudes', 'perceptions', 'air', 'quality']
# Verbs are:  []
# ['Air quality']
# Var name is:  air quality
# Nouns are:  ['air', 'quality']
# Verbs are:  []
# ['Source of pollution']
# Var name is:  source of pollution
# Nouns are:  ['source', 'pollution']
# Verbs are:  []
# ['Personal cotribution to air pollution']
# Var name is:  personal cotribution to air pollution
# Nouns are:  ['cotribution', 'air', 'pollution']
# Verbs are:  []
# ['Consequences of air pollution']
# Var name is:  consequences of air pollution
# Nouns are:  ['consequences', 'air', 'pollution']
# Verbs are:  []
# ['Contribution of air pollution to illness']
# Var name is:  contribution of air pollution to illness
# Nouns are:  ['contribution', 'air', 'pollution']
# Verbs are:  ['illness']
# ['Stength of linkage between air quality and human health']
# Var name is:  stength of linkage between air quality and human health
# Nouns are:  ['stength', 'linkage', 'air', 'quality', 'health']
# Verbs are:  []
# ['Importance of air quality improvement']
# Var name is:  importance of air quality improvement
# Nouns are:  ['importance', 'air', 'quality', 'improvement']
# Verbs are:  []
# ['Effect of air quality impovemet program on job']
# Var name is:  effect of air quality impovemet program on job
# Nouns are:  ['effect', 'air', 'quality', 'program', 'job']
# Verbs are:  ['impovemet']
# ['Commitment']
# Var name is:  commitment
# Nouns are:  ['commitment']
# Verbs are:  []
# ['Knowledge about air pollution compared to others']
# Var name is:  knowledge about air pollution compared to others
# Nouns are:  ['knowledge', 'air', 'pollution', 'others']
# Verbs are:  ['compared']
# ['Module 4: Water']
# Var name is:  water
# Nouns are:  ['water']
# Verbs are:  []
# ['Source of water']
# Var name is:  source of water
# Nouns are:  ['source', 'water']
# Verbs are:  []
# ['Quality']
# Var name is:  quality
# Nouns are:  ['quality']
# Verbs are:  []
# ['Water payment']
# Var name is:  water payment
# Nouns are:  ['water', 'payment']
# Verbs are:  []
# ['Method to collect water']
# Var name is:  method to collect water
# Nouns are:  ['method', 'water']
# Verbs are:  ['collect']
# ['Source of water by neighbours']
# Var name is:  source of water by neighbours
# Nouns are:  ['source', 'water', 'neighbours']
# Verbs are:  []
# ['Source of water for vendors']
# Var name is:  source of water for vendors
# Nouns are:  ['source', 'water', 'vendors']
# Verbs are:  []
# ['Water quantity']
# Var name is:  water quantity
# Nouns are:  ['water', 'quantity']
# Verbs are:  []
# ['Water charges']
# Var name is:  water charges
# Nouns are:  ['water', 'charges']
# Verbs are:  []
# ['Complaints on piped water system']
# Var name is:  complaints on piped water system
# Nouns are:  ['complaints', 'water', 'system']
# Verbs are:  []
# ['Method to collect water from well']
# Var name is:  method to collect water from well
# Nouns are:  ['method', 'water']
# Verbs are:  ['collect']
# ['Tye of rainwater collection system used']
# Var name is:  tye of rainwater collection system used
# Nouns are:  ['tye', 'rainwater', 'collection', 'system']
# Verbs are:  ['used']
# ['Module 5: Household Sanitation - Attitudes and Practices']
# Var name is:  household sanitation - attitudes and practices
# Nouns are:  ['household', 'sanitation', 'attitudes', 'practices']
# Verbs are:  []
# ['Quality']
# Var name is:  quality
# Nouns are:  ['quality']
# Verbs are:  []
# ['Place where toilet waste is discharged']
# Var name is:  place where toilet waste is discharged
# Nouns are:  ['place', 'toilet', 'waste']
# Verbs are:  ['is', 'discharged']
# ['Method used to empty septic tank']
# Var name is:  method used to empty septic tank
# Nouns are:  ['method', 'tank']
# Verbs are:  ['used', 'empty']
# ['Satisfaction']
# Var name is:  satisfaction
# Nouns are:  ['satisfaction']
# Verbs are:  []
# ['Quality']
# Var name is:  quality
# Nouns are:  ['quality']
# Verbs are:  []
# ['Place members go to relieve themselves']
# Var name is:  place members go to relieve themselves
# Nouns are:  ['place', 'members']
# Verbs are:  ['go', 'relieve']
# ['Module 6A: Fuel Sources and Uses']
# Var name is:  fuel sources and uses
# Nouns are:  ['fuel', 'sources', 'uses']
# Verbs are:  []
# ['Souce of fuel']
# Var name is:  souce of fuel
# Nouns are:  ['souce', 'fuel']
# Verbs are:  []
# ['Primary', 'Secondary']
# Var name is:  primary
# Nouns are:  ['primary']
# Verbs are:  []
# ['Module 6B: Detail on Fuel by Source']
# Var name is:  detail on fuel by source
# Nouns are:  ['detail', 'fuel', 'source']
# Verbs are:  []
# ['Fuel purpose']
# Var name is:  fuel purpose
# Nouns are:  ['fuel', 'purpose']
# Verbs are:  []
# ['Members who collects fuel source']
# Var name is:  members who collects fuel source
# Nouns are:  ['members', 'fuel', 'source']
# Verbs are:  ['collects']
# ['Proportions']
# Var name is:  proportions
# Nouns are:  ['proportions']
# Verbs are:  []
# ['Source of dung']
# Var name is:  source of dung
# Nouns are:  ['source', 'dung']
# Verbs are:  []
# ['Module 7: Households’ Willingness to Pay for Improved Water Service - An Example of a Contingent Valuation Scenario (Urban) ']
# Var name is:  households’ willingness to pay for improved water service - an example of a contingent valuation scenario (urban)
# Nouns are:  ['households', 'willingness', 'water', 'service', 'example', 'valuation', 'scenario']
# Verbs are:  ['’', 'pay']
# ['Vote for the new water supply project ']
# Var name is:  vote for the new water supply project
# Nouns are:  ['vote', 'water', 'supply', 'project']
# Verbs are:  []
# ['Would want to be connected to the new water supply system ']
# Var name is:  would want to be connected to the new water supply system
# Nouns are:  ['water', 'supply', 'system']
# Verbs are:  ['want', 'be', 'connected']
# ['Module 8: Households’ Willingness to Pay for Improved Water Service - An Example of a Contingent Valuation Scenario (Rural - Public Taps Only)']
# Var name is:  households’ willingness to pay for improved water service - an example of a contingent valuation scenario (rural - public taps only)
# Nouns are:  ['households', 'willingness', 'water', 'service', 'example', 'valuation', 'scenario', 'taps']
# Verbs are:  ['’', 'pay']
# ['Would pay monthly fee and use public taps']
# Var name is:  would pay monthly fee and use public taps
# Nouns are:  ['fee', 'taps']
# Verbs are:  ['pay', 'use']
# ['Would buy water from public taps']
# Var name is:  would buy water from public taps
# Nouns are:  ['water', 'taps']
# Verbs are:  ['buy']
# ['Preferred payment system for public taps ']
# Var name is:  preferred payment system for public taps
# Nouns are:  ['payment', 'system', 'taps']
# Verbs are:  ['preferred']
# ['Module 9: Households’ Willingness to Pay for Improved Sanitation - An Example of a Contingent Valuation Scenario for Sewer Connection (Urban)']
# Var name is:  households’ willingness to pay for improved sanitation - an example of a contingent valuation scenario for sewer connection (urban)
# Nouns are:  ['households', 'willingness', 'sanitation', 'example', 'valuation', 'scenario', 'connection']
# Verbs are:  ['’', 'pay']
# ['Familiarity']
# Var name is:  familiarity
# Nouns are:  ['familiarity']
# Verbs are:  []
# ['Reason for not willing to pay ']
# Var name is:  reason for not willing to pay
# Nouns are:  ['reason']
# Verbs are:  ['pay']
# ['Main reason for agreeing to pay ']
# Var name is:  main reason for agreeing to pay
# Nouns are:  ['reason']
# Verbs are:  ['agreeing', 'pay']
# ['Item would reduce expenditure to afford monthly fee']
# Var name is:  item would reduce expenditure to afford monthly fee
# Nouns are:  ['item', 'expenditure', 'fee']
# Verbs are:  ['reduce', 'afford']
# ['Module 10: Households’ Willingness to Pay for Improved Urban Air Quality - An Example of a Contingent Valuation Scenario ']
# Var name is:  households’ willingness to pay for improved urban air quality - an example of a contingent valuation scenario
# Nouns are:  ['households', 'willingness', 'air', 'quality', 'example', 'valuation', 'scenario']
# Verbs are:  ['’', 'pay']
# ['Would vote for air pollution clean-up plan ']
# Var name is:  would vote for air pollution clean-up plan
# Nouns are:  ['air', 'pollution', 'clean-up', 'plan']
# Verbs are:  ['vote']
# ['Certainity']
# Var name is:  certainity
# Nouns are:  ['certainity']
# Verbs are:  []
# ['Fertility']
# Var name is:  fertility
# Nouns are:  ['fertility']
# Verbs are:  []
# ['Part A: Maternity History']
# Var name is:  maternity history
# Nouns are:  ['maternity', 'history']
# Verbs are:  []
# ['Sex of child']
# Var name is:  sex of child
# Nouns are:  ['sex', 'child']
# Verbs are:  []
# ['Single', 'Multiple']
# Var name is:  single
# Nouns are:  []
# Verbs are:  []
# ['Want the child ']
# Var name is:  want the child
# Nouns are:  ['child']
# Verbs are:  ['want']
# ['Desire for more children']
# Var name is:  desire for more children
# Nouns are:  ['desire', 'children']
# Verbs are:  []
# ['Part B: Reproductive Health']
# Var name is:  reproductive health
# Nouns are:  ['health']
# Verbs are:  []
# ['Assitance at delivery']
# Var name is:  assitance at delivery
# Nouns are:  ['assitance', 'delivery']
# Verbs are:  []
# ['Place of delivery']
# Var name is:  place of delivery
# Nouns are:  ['place', 'delivery']
# Verbs are:  []
# ['Part C: Contraceptive Use']
# Var name is:  contraceptive use
# Nouns are:  ['contraceptive', 'use']
# Verbs are:  []
# ['Contraception method']
# Var name is:  contraception method
# Nouns are:  ['contraception', 'method']
# Verbs are:  []
# ['Place first heard of']
# Var name is:  place first heard of
# Nouns are:  ['place', 'heard']
# Verbs are:  []
# ['Reason for not using']
# Var name is:  reason for not using
# Nouns are:  ['reason']
# Verbs are:  ['using']
# ['Place obtained']
# Var name is:  place obtained
# Nouns are:  ['place']
# Verbs are:  ['obtained']
# ['Migration']
# Var name is:  migration
# Nouns are:  ['migration']
# Verbs are:  []
# ['Short Module (Migration)']
# Var name is:  short module (migration)
# Nouns are:  ['module', 'migration']
# Verbs are:  []
# ['Reason for moving here ']
# Var name is:  reason for moving here
# Nouns are:  ['reason']
# Verbs are:  ['moving']
# ['Facilities affected decision to move her']
# Var name is:  facilities affected decision to move her
# Nouns are:  ['facilities', 'decision']
# Verbs are:  ['affected', 'move']
# ['Person who already lived here']
# Var name is:  person who already lived here
# Nouns are:  ['person']
# Verbs are:  ['lived']
# ['Person(s) lived with when first moved here ']
# Var name is:  person(s) lived with when first moved here
# Nouns are:  ['person', 's']
# Verbs are:  ['lived', 'moved']
# ['Reason for not working in the last month lived in previous place of residence ']
# Var name is:  reason for not working in the last month lived in previous place of residence
# Nouns are:  ['reason', 'month', 'place', 'residence']
# Verbs are:  ['working', 'lived']
# ['Main means of support before finding the first work']
# Var name is:  main means of support before finding the first work
# Nouns are:  ['means', 'support', 'work']
# Verbs are:  ['finding']
# ['Method used to find the first wage work ']
# Var name is:  method used to find the first wage work
# Nouns are:  ['method', 'wage', 'work']
# Verbs are:  ['used', 'find']
# ['Yes', 'No', 'Blank']
# Var name is:  yes
# Nouns are:  ['yes']
# Verbs are:  []
# ['Filter for been living here for more than 5 years ']
# Var name is:  filter for been living here for more than 5 years
# Nouns are:  ['filter', 'years']
# Verbs are:  ['been', 'living']
# ['Relationship to person living in the same dwelling']
# Var name is:  relationship to person living in the same dwelling
# Nouns are:  ['relationship', 'person', 'dwelling']
# Verbs are:  ['living']
# ['Main activity']
# Var name is:  main activity
# Nouns are:  ['activity']
# Verbs are:  []
# ['Lives in Country', ' Lives abroad']
# Var name is:  lives in country
# Nouns are:  ['lives', 'country']
# Verbs are:  []
# ['Major field of study in post secondary education ']
# Var name is:  major field of study in post secondary education
# Nouns are:  ['field', 'study', 'post', 'education']
# Verbs are:  []
# ['Type of school']
# Var name is:  type of school
# Nouns are:  ['type', 'school']
# Verbs are:  []
# ['Contributor to pay fees']
# Var name is:  contributor to pay fees
# Nouns are:  ['contributor', 'fees']
# Verbs are:  ['pay']

# %%
mics_classification = parse_qualitative_variables(mics, 'breakdown_of_mics_qualitative_variables.csv')

# %%
ipums_classification = parse_qualitative_variables(ipums, 'breakdown_of_ipums_qualitative_variables.csv')

# %%
dhs2_classification = parse_qualitative_variables(dhs2, 'breakdown_of_dhs2_qualitative_variables.csv')

# %%
svo.is_cat('cooking','process',out='short')
# Out:
# True

# %%
search_ontology_for_class('cooking')
# Out:
# ['Process', 'NamedIndividual']
